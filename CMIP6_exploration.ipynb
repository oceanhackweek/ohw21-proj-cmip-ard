# %% [markdown]
# # CMIP Exploration

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray

from dask.diagnostics import ProgressBar
import intake

# %% [markdown]
# ## Loading data and exploring

# %%
col = intake.open_esm_datastore("https://storage.googleapis.com/cmip6/pangeo-cmip6.json")

# %%
col.df
# Out:
#         activity_id institution_id     source_id       experiment_id  \
# 0        HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present
# 1        HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present
# 2        HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present
# 3        HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present
# 4        HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present
# ...             ...            ...           ...                 ...
# 511420         CMIP           CMCC  CMCC-CM2-HR4        abrupt-4xCO2
# 511421         CMIP           CMCC  CMCC-CM2-HR4        abrupt-4xCO2
# 511422         CMIP           CMCC  CMCC-CM2-HR4        abrupt-4xCO2
# 511423  ScenarioMIP        AS-RCEC       TaiESM1              ssp585
# 511424  ScenarioMIP        AS-RCEC       TaiESM1              ssp585
#
#        member_id table_id variable_id grid_label  \
# 0       r1i1p1f1     Amon        hfls         gn
# ...

# %%
# Print information about the source IDs
np.sort(col.df['source_id'].unique())
# Out:
# array(['ACCESS-CM2', 'ACCESS-ESM1-5', 'AWI-CM-1-1-MR', 'AWI-ESM-1-1-LR',
#        'BCC-CSM2-HR', 'BCC-CSM2-MR', 'BCC-ESM1', 'CAMS-CSM1-0',
#        'CAS-ESM2-0', 'CESM1-1-CAM5-CMIP5', 'CESM1-WACCM-SC', 'CESM2',
#        'CESM2-FV2', 'CESM2-WACCM', 'CESM2-WACCM-FV2', 'CIESM',
#        'CMCC-CM2-HR4', 'CMCC-CM2-SR5', 'CMCC-CM2-VHR4', 'CMCC-ESM2',
#        'CNRM-CM6-1', 'CNRM-CM6-1-HR', 'CNRM-ESM2-1', 'CanESM5',
#        'CanESM5-CanOE', 'E3SM-1-0', 'E3SM-1-1', 'E3SM-1-1-ECA',
#        'EC-Earth3', 'EC-Earth3-AerChem', 'EC-Earth3-CC', 'EC-Earth3-LR',
#        'EC-Earth3-Veg', 'EC-Earth3-Veg-LR', 'EC-Earth3P', 'EC-Earth3P-HR',
#        'EC-Earth3P-VHR', 'ECMWF-IFS-HR', 'ECMWF-IFS-LR', 'FGOALS-f3-H',
#        'FGOALS-f3-L', 'FGOALS-g3', 'FIO-ESM-2-0', 'GFDL-AM4', 'GFDL-CM4',
#        'GFDL-CM4C192', 'GFDL-ESM2M', 'GFDL-ESM4', 'GFDL-OM4p5B',
#        'GISS-E2-1-G', 'GISS-E2-1-G-CC', 'GISS-E2-1-H', 'GISS-E2-2-G',
#        'HadGEM3-GC31-HM', 'HadGEM3-GC31-LL', 'HadGEM3-GC31-LM',
# ...

# %%
# Print information about the experiments
col.df.groupby('experiment_id').size().sort_values(ascending=False).iloc[0:10]
# Out:
# experiment_id
# dcppA-hindcast    141016
# historical         81347
# ssp245             39586
# ssp585             33642
# ssp370             30183
# ssp126             27575
# abrupt-4xCO2       12218
# 1pctCO2            11765
# piControl          10123
# ssp119              9951
# dtype: int64

# %%
# Seems to be an issue here: activity_id should be something like CMIP instead of CSIRO
col.df[col.df['source_id']=='ssp585']
# Out:
#        activity_id institution_id source_id experiment_id member_id table_id  \
# 508944       CSIRO  ACCESS-ESM1-5    ssp585      r5i1p1f1       day      hus
# 509015       CSIRO  ACCESS-ESM1-5    ssp585      r4i1p1f1       day      hus
#
#        variable_id grid_label  \
# 508944          gn  v20210318
# 509015          gn  v20210318
#
#                                                    zstore  dcpp_init_year  \
# 508944  gs://cmip6/CMIP6/ScenarioMIP/CSIRO/ACCESS-ESM1...             NaN
# 509015  gs://cmip6/CMIP6/ScenarioMIP/CSIRO/ACCESS-ESM1...             NaN
#
#          version
# 508944  20210318
# 509015  20210318

# %%
# Find all models which have both 'tos' and 'no3os' variables

# %% [markdown]
# ## Selecting specific models and experiments

# %%
variables = ['tos', 'no3os']
experiments = ['historical', 'ssp585']

cat = col.search(
    variable_id=variables,
    grid_label='gn',
    table_id='Omon',
    member_id=['r1i1p1f1', 'r2i1p1f1']
)

ddict = cat.to_dataset_dict(
    zarr_kwargs={'consolidated':True, 'use_cftime':True}, # recommended for faster reading and better time handling
    storage_options={'token': 'anon'}, # needed to access the public CMIP6 data on google
    aggregate=False,
)
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.member_id.table_id.variable_id.grid_label.zstore.dcpp_init_year.version'
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='90' class='' max='811' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.10% [90/811 00:06<00:54]
#     </div>
# ---------------------------------------------------------------------------
# ...
